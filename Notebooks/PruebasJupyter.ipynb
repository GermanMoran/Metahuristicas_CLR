# %%
# Dependencias
import random
import pandas as pd
import numpy as np 
# Data visualization
from matplotlib import pyplot as plot
import statsmodels.api as sm
from statistics import mode
from   scipy import stats
import numpy                   as np
import matplotlib.pyplot       as plt
import seaborn                 as sns
import statsmodels.formula.api as sm
#librerias y Dependencias a Utilizar
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
#df = pd.read_excel('datasetNuevo.csv', sep=';')
# Carga de datos
df = pd.read_excel('prueba.xlsx',engine='openpyxl')

# %%
df.tail(10)
# Out:
#     TIPO_SIEMBRA SEM_TRATADAS  DIST_SURCOS  DIST_PLANTAS COLOR_ENDOSPERMO  \
# 737   Mecanizado           NO          0.8          0.20         Amarillo
# 738   Mecanizado           NO          0.8          0.18         Amarillo
# 739   Mecanizado           NO          0.8          0.18         Amarillo
# 740   Mecanizado           NO          0.8          0.20         Amarillo
# 741       Manual           NO          0.8          0.40         Amarillo
# 742       Manual           NO          0.8          0.40         Amarillo
# 743   Mecanizado           NO          0.8          0.20           Blanco
# 744   Mecanizado           NO          0.8          0.20           Blanco
# 745   Mecanizado           NO          0.8          0.18           Blanco
# 746   Mecanizado           NO          0.8          0.18           Blanco
#
#      SEM_POR_SITIO    MATERIAL_GENETICO CULT_ANT DRENAJE METODO_COSECHA  ...  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=747, step=1)

# %%
print(len(df))
# Out:
# 747

# %%
#Funcion que genera el individuo/cromosoma inicial de tamaño nDim
def vectorSolution(nDim,rango):
    s= []
    for i in range(nDim):
        s.append(random.randint(1, rango))    
    return s

# %%
s = vectorSolution(747,5)
print(s)
# Out:
# [5, 1, 4, 5, 2, 3, 2, 4, 2, 2, 5, 1, 3, 3, 3, 2, 3, 3, 3, 2, 5, 2, 2, 2, 3, 2, 2, 5, 2, 2, 1, 4, 1, 2, 3, 2, 3, 5, 5, 4, 5, 4, 3, 1, 5, 4, 1, 5, 4, 5, 2, 5, 2, 4, 5, 1, 1, 5, 1, 4, 2, 2, 2, 5, 2, 1, 2, 3, 5, 4, 5, 1, 5, 5, 5, 3, 1, 5, 1, 4, 2, 2, 4, 2, 5, 5, 4, 4, 4, 1, 3, 2, 3, 2, 2, 4, 2, 4, 2, 4, 2, 4, 2, 2, 2, 4, 2, 1, 1, 4, 4, 4, 5, 2, 1, 3, 5, 5, 3, 5, 5, 1, 4, 4, 5, 2, 1, 5, 1, 4, 2, 4, 1, 3, 5, 1, 2, 2, 2, 2, 4, 4, 2, 2, 5, 5, 5, 4, 5, 3, 3, 1, 2, 3, 3, 1, 5, 3, 3, 2, 1, 2, 1, 4, 2, 2, 4, 3, 1, 3, 3, 1, 4, 2, 3, 5, 2, 2, 5, 5, 4, 2, 3, 5, 3, 1, 1, 2, 2, 1, 5, 3, 3, 2, 1, 2, 1, 2, 2, 5, 2, 4, 1, 2, 4, 3, 1, 3, 5, 1, 5, 2, 3, 1, 1, 2, 3, 4, 1, 5, 2, 5, 5, 1, 2, 1, 2, 2, 1, 1, 4, 5, 2, 5, 4, 5, 5, 5, 5, 2, 2, 3, 3, 4, 5, 4, 5, 2, 5, 1, 2, 2, 3, 3, 1, 4, 4, 2, 1, 4, 2, 4, 5, 4, 3, 2, 3, 2, 3, 1, 1, 1, 5, 5, 5, 2, 3, 5, 1, 1, 4, 2, 5, 3, 2, 3, 3, 4, 1, 3, 5, 5, 1, 2, 4, 4, 4, 5, 1, 1, 1, 4, 4, 2, 1, 5, 2, 4, 2, 1, 1, 1, 3, 5, 4, 5, 1, 4, 2, 3, 4, 2, 3, 4, 1, 1, 3, 2, 5, 5, 1, 2, 2
# ...

# %%
lista,fitnes = fitnesIndividuo(df,s,clusters)
# Out:
# Longitud cluster:  149
# Tamaño del Cluster:  149
# Longitud cluster:  177
# Tamaño del Cluster:  177
# Longitud cluster:  128
# Tamaño del Cluster:  128
# Longitud cluster:  141
# Tamaño del Cluster:  141
# Longitud cluster:  152
# Tamaño del Cluster:  152

# %%
vectorArray = np.array(s)

# %% [markdown]
# ## PRUEBAS INDIVIDUALES POR CLUSTER

# %%
# Agrupamos los datos priemr cluster
cls1 =  np.where(vectorArray == 1)
print(type(cls1[0]))
list_cls1 = cls1[0].flatten().tolist()
print(list_cls1)

# Filtramos el datset deacuerdo a esos indices
df_cls1 = df[df.index.isin(list_cls1)==True]
df_cls1
print(len(df_cls1))
# Ya tengo los datos del primer cluster - creo mi modelo de regresion lineal
# Out:
# <class 'numpy.ndarray'>
# [4, 13, 14, 16, 20, 25, 27, 28, 29, 40, 41, 46, 47, 49, 50, 52, 58, 61, 76, 84, 85, 88, 91, 92, 93, 98, 99, 102, 106, 107, 111, 120, 125, 129, 136, 142, 151, 156, 157, 159, 160, 167, 168, 169, 172, 181, 190, 196, 201, 222, 226, 227, 228, 236, 246, 247, 253, 254, 261, 265, 266, 267, 268, 272, 274, 276, 284, 285, 294, 302, 305, 308, 322, 330, 331, 335, 340, 356, 359, 375, 378, 382, 387, 394, 397, 400, 403, 410, 412, 416, 425, 433, 434, 441, 442, 454, 466, 477, 480, 481, 500, 504, 508, 509, 521, 527, 544, 548, 555, 556, 557, 560, 561, 564, 566, 577, 584, 589, 592, 595, 597, 598, 600, 602, 624, 625, 628, 635, 642, 645, 646, 647, 656, 669, 672, 675, 694, 700, 708, 709, 710, 712, 713, 715, 718, 725, 736, 737, 740, 743]
# 150

# %%
# Se divide el dataset en conjunto de entrenamiento y pruebas [0.8 : Entrenamiento; 0.3: Testeo]
data_train, data_test = train_test_split(df_cls1, test_size=0.3, random_state=42)
variables_independientes = '''~ C(MATERIAL_GENETICO) + C(TIPO_MATERIAL) +C(POSICION_PERFIL_RASTA) +C(ESTRUCTURA_RASTA) + C(OBSERVA_COSTRAS_DURAS_RASTA)
                                + C(OBSERVA_COSTRAS_BLANCAS_RASTA) + C(OBSERVA_COSTAS_NEGRAS_RASTA) + C(OBSERVA_PLANTAS_PEQUENAS_RASTA) + C(RECUBRIMIENTO_VEGETAL__SUELO_RASTA)
                                + C(TIPO_SIEMBRA)+ C(SEM_TRATADAS) + C(DIAS_EN_FLORECER_A_COSECHAR) +ContEnfQui_Emer_Flor + ContMalQui_Antes_Siem + ContMalQui_Emer_Flor
                                + ContPlaQui_Siem_Emer + PROFUND_RAICES_VIVAS_RASTA + Porc_Ar + Porc_FAr + Porc_BLANDO + Porc_FIRME + Porc_MUY_PLASTICO
'''
# Se define el modelo
modcl1 = smf.ols(formula='RDT_AJUSTADO'+variables_independientes, data=data_train).fit()
#Resumen del modelo de 30 variables
#print(modcl1.summary())
modcl1.rsquared_adj
# Out:
# 0.6087699685221186

# %%
# AGRUPAMOS LOS DATOS DEL SEGUNDO CLUSTER

cls2 =  np.where(vectorArray == 2)
list_cls2 = cls2[0].flatten().tolist()
# Filtramos el datset deacuerdo a esos indices
df_cls2 = df[df.index.isin(list_cls2)==True]
df_cls2
print(len(df_cls2))
# Se divide el dataset en conjunto de entrenamiento y pruebas [0.7 : Entrenamiento; 0.3: Testeo]
data_train, data_test = train_test_split(df_cls2, test_size=0.3, random_state=42)
variables_independientes = '''~ C(MATERIAL_GENETICO) + C(TIPO_MATERIAL) +C(POSICION_PERFIL_RASTA) +C(ESTRUCTURA_RASTA) + C(OBSERVA_COSTRAS_DURAS_RASTA)
                                + C(OBSERVA_COSTRAS_BLANCAS_RASTA) + C(OBSERVA_COSTAS_NEGRAS_RASTA) + C(OBSERVA_PLANTAS_PEQUENAS_RASTA) + C(RECUBRIMIENTO_VEGETAL__SUELO_RASTA)
                                + C(TIPO_SIEMBRA)+ C(SEM_TRATADAS) + C(DIAS_EN_FLORECER_A_COSECHAR) +ContEnfQui_Emer_Flor + ContMalQui_Antes_Siem + ContMalQui_Emer_Flor
                                + ContPlaQui_Siem_Emer + PROFUND_RAICES_VIVAS_RASTA + Porc_Ar + Porc_FAr + Porc_BLANDO + Porc_FIRME + Porc_MUY_PLASTICO
'''
# Se define el modelo
modcls2 = smf.ols(formula='RDT_AJUSTADO'+variables_independientes, data=data_train).fit()
#Resumen del modelo de 30 variables
modcls2.rsquared_adj
# Out:
# 154
# 0.5135786737328911

# %%
# Agrupamos los datos priemr cluster
cls3 =  np.where(vectorArray == 3)
list_cls3 = cls3[0].flatten().tolist()
# Filtramos el datset deacuerdo a esos indices
df_cls3 = df[df.index.isin(list_cls3)==True]
df_cls3
print(len(df_cls3))
# Se divide el dataset en conjunto de entrenamiento y pruebas [0.7 : Entrenamiento; 0.3: Testeo]
data_train, data_test = train_test_split(df_cls3, test_size=0.3, random_state=42)
variables_independientes = '''~ C(MATERIAL_GENETICO) + C(TIPO_MATERIAL) +C(POSICION_PERFIL_RASTA) +C(ESTRUCTURA_RASTA) + C(OBSERVA_COSTRAS_DURAS_RASTA)
                                + C(OBSERVA_COSTRAS_BLANCAS_RASTA) + C(OBSERVA_COSTAS_NEGRAS_RASTA) + C(OBSERVA_PLANTAS_PEQUENAS_RASTA) + C(RECUBRIMIENTO_VEGETAL__SUELO_RASTA)
                                + C(TIPO_SIEMBRA)+ C(SEM_TRATADAS) + C(DIAS_EN_FLORECER_A_COSECHAR) +ContEnfQui_Emer_Flor + ContMalQui_Antes_Siem + ContMalQui_Emer_Flor
                                + ContPlaQui_Siem_Emer + PROFUND_RAICES_VIVAS_RASTA + Porc_Ar + Porc_FAr + Porc_BLANDO + Porc_FIRME + Porc_MUY_PLASTICO
'''
# Se define el modelo
modcls3 = smf.ols(formula='RDT_AJUSTADO'+variables_independientes, data=data_train).fit()
#Resumen del modelo de 30 variables
modcls3.rsquared_adj
# Out:
# 147
# 0.6250745883554271

# %%
# Agrupamos los datos priemr cluster
cls4 =  np.where(vectorArray == 4)
list_cls4 = cls4[0].flatten().tolist()
# Filtramos el datset deacuerdo a esos indices
df_cls4 = df[df.index.isin(list_cls4)==True]
df_cls4
print(len(df_cls4))
# Se divide el dataset en conjunto de entrenamiento y pruebas [0.7 : Entrenamiento; 0.3: Testeo]
data_train, data_test = train_test_split(df_cls4, test_size=0.3, random_state=42)
variables_independientes = '''~ C(MATERIAL_GENETICO) + C(TIPO_MATERIAL) +C(POSICION_PERFIL_RASTA) +C(ESTRUCTURA_RASTA) + C(OBSERVA_COSTRAS_DURAS_RASTA)
                                + C(OBSERVA_COSTRAS_BLANCAS_RASTA) + C(OBSERVA_COSTAS_NEGRAS_RASTA) + C(OBSERVA_PLANTAS_PEQUENAS_RASTA) + C(RECUBRIMIENTO_VEGETAL__SUELO_RASTA)
                                + C(TIPO_SIEMBRA)+ C(SEM_TRATADAS) + C(DIAS_EN_FLORECER_A_COSECHAR) +ContEnfQui_Emer_Flor + ContMalQui_Antes_Siem + ContMalQui_Emer_Flor
                                + ContPlaQui_Siem_Emer + PROFUND_RAICES_VIVAS_RASTA + Porc_Ar + Porc_FAr + Porc_BLANDO + Porc_FIRME + Porc_MUY_PLASTICO
'''
# Se define el modelo
modcls4 = smf.ols(formula='RDT_AJUSTADO'+variables_independientes, data=data_train).fit()
#Resumen del modelo de 30 variables
modcls4.rsquared_adj
# Out:
# 160
# 0.5331573423524889

# %%
# Agrupamos los datos priemr cluster
cls5 =  np.where(vectorArray == 5)
list_cls5 = cls5[0].flatten().tolist()
# Filtramos el datset deacuerdo a esos indices
df_cls5 = df[df.index.isin(list_cls5)==True]
df_cls5
print(len(df_cls5))

# Se divide el dataset en conjunto de entrenamiento y pruebas [0.7 : Entrenamiento; 0.3: Testeo]
data_train, data_test = train_test_split(df_cls5, test_size=0.3, random_state=42)
variables_independientes = '''~ C(MATERIAL_GENETICO) + C(TIPO_MATERIAL) +C(POSICION_PERFIL_RASTA) +C(ESTRUCTURA_RASTA) + C(OBSERVA_COSTRAS_DURAS_RASTA)
                                + C(OBSERVA_COSTRAS_BLANCAS_RASTA) + C(OBSERVA_COSTAS_NEGRAS_RASTA) + C(OBSERVA_PLANTAS_PEQUENAS_RASTA) + C(RECUBRIMIENTO_VEGETAL__SUELO_RASTA)
                                + C(TIPO_SIEMBRA)+ C(SEM_TRATADAS) + C(DIAS_EN_FLORECER_A_COSECHAR) +ContEnfQui_Emer_Flor + ContMalQui_Antes_Siem + ContMalQui_Emer_Flor
                                + ContPlaQui_Siem_Emer + PROFUND_RAICES_VIVAS_RASTA + Porc_Ar + Porc_FAr + Porc_BLANDO + Porc_FIRME + Porc_MUY_PLASTICO
'''
# Se define el modelo
modcls5 = smf.ols(formula='RDT_AJUSTADO'+variables_independientes, data=data_train).fit()
#Resumen del modelo de 30 variables
modcls5.rsquared_adj
# Out:
# 160
# 0.5111932285053316

# %%
# Numero de registros
len(df)
# Out:
# 747

# %% [markdown]
# ## FUNCION FITNES R-AJUSTADO

# %%
# Funcion para obtener el valor de Aptitud (Fitness) de cada individuo


clusters = 5
def fitnesIndividuo(df,individuo,Clusters,contEvaluacion):
    # Contador del numero de veces de la función Objetivo
    contEvaluacion = contEvaluacion+1
    listFitnes = []
    # Se realizan los respectivos filtros
    for i in range(Clusters):
        vectorArray = np.array(individuo)
        cls =  np.where(vectorArray == (i+1))
        list_cls = cls[0].flatten().tolist()
        # Se filtra el dataset deacuerdo a esos indices
        df_cls = df[df.index.isin(list_cls)==True]
        print("Longitud cluster: ",len(df_cls))
        # Se realiza el llamado a la función lineal
        fitnes_cls = RegresionLineal(df_cls)
        listFitnes.append(fitnes_cls)
    
    # Fitnes solucion
    FitnesSoluccion = sum(listFitnes)/len(df)
    return FitnesSoluccion,contEvaluacion

# %%
def RegresionLineal(df_cls):
    Pond_Radjustado = len(df_cls)
    print("Tamaño del Cluster: ",Pond_Radjustado)
    # Se divide el dataset en conjunto de entrenamiento y pruebas [0.7 : Entrenamiento; 0.3: Testeo]
    data_train, data_test = train_test_split(df_cls, test_size=0.3, random_state=42)
    variables_independientes = '''~ C(MATERIAL_GENETICO) + C(TIPO_MATERIAL) +C(POSICION_PERFIL_RASTA) +C(ESTRUCTURA_RASTA) + C(OBSERVA_COSTRAS_DURAS_RASTA)
                                    + C(OBSERVA_COSTRAS_BLANCAS_RASTA) + C(OBSERVA_COSTAS_NEGRAS_RASTA) + C(OBSERVA_PLANTAS_PEQUENAS_RASTA) + C(RECUBRIMIENTO_VEGETAL__SUELO_RASTA)
                                    + C(TIPO_SIEMBRA)+ C(SEM_TRATADAS) + C(DIAS_EN_FLORECER_A_COSECHAR) +ContEnfQui_Emer_Flor + ContMalQui_Antes_Siem + ContMalQui_Emer_Flor
                                    + ContPlaQui_Siem_Emer + PROFUND_RAICES_VIVAS_RASTA + Porc_Ar + Porc_FAr + Porc_BLANDO + Porc_FIRME + Porc_MUY_PLASTICO
    '''
    # Se crea el modelo
    mod_cls = smf.ols(formula='RDT_AJUSTADO'+variables_independientes, data=data_train).fit()
    #Me retorna el valor de la metrica de desempeño  para ese cluster.
    fitnes_cls = mod_cls.rsquared_adj * Pond_Radjustado
    return fitnes_cls

# %%
# Pruebas de las Funciones
print(s)
# Out:
# [2, 5, 2, 5, 4, 1, 2, 1, 3, 3, 4, 1, 2, 4, 4, 2, 4, 5, 4, 1, 1, 1, 5, 3, 5, 3, 5, 4, 3, 1, 1, 2, 3, 4, 1, 3, 1, 1, 2, 4, 4, 5, 1, 5, 3, 1, 1, 2, 3, 5, 1, 3, 4, 3, 2, 5, 4, 1, 4, 4, 1, 5, 3, 4, 3, 5, 1, 4, 2, 1, 4, 1, 1, 5, 4, 3, 2, 3, 1, 5, 1, 5, 4, 5, 2, 3, 5, 1, 3, 1, 1, 2, 2, 5, 3, 4, 2, 3, 2, 2, 1, 4, 5, 1, 4, 2, 1, 2, 5, 1, 3, 2, 3, 2, 1, 2, 3, 1, 3, 3, 4, 2, 1, 5, 4, 2, 5, 1, 2, 3, 5, 3, 3, 2, 3, 1, 4, 1, 4, 1, 1, 1, 1, 2, 1, 1, 2, 5, 2, 4, 4, 3, 4, 1, 3, 5, 2, 1, 3, 1, 4, 1, 3, 1, 1, 4, 5, 3, 1, 1, 1, 1, 5, 5, 3, 4, 5, 2, 4, 5, 4, 3, 4, 5, 3, 2, 2, 1, 4, 3, 5, 4, 1, 1, 5, 1, 5, 4, 4, 3, 1, 3, 5, 4, 3, 1, 3, 2, 4, 5, 1, 5, 3, 4, 4, 2, 3, 1, 1, 2, 3, 2, 4, 5, 5, 5, 1, 3, 1, 3, 3, 4, 5, 1, 5, 5, 2, 3, 1, 4, 1, 4, 5, 4, 5, 2, 2, 1, 5, 1, 2, 5, 2, 5, 1, 2, 5, 5, 3, 5, 3, 2, 2, 1, 1, 1, 2, 3, 5, 3, 2, 4, 2, 4, 5, 4, 3, 4, 1, 3, 3, 4, 3, 5, 1, 3, 3, 4, 1, 3, 2, 1, 3, 4, 4, 2, 2, 3, 2, 5, 5, 4, 3, 1, 2, 5, 2, 3, 1, 3, 3, 3, 2, 1, 1, 2, 4, 2, 5, 5, 2, 5, 3, 1, 1, 3, 3, 3, 3, 3, 2, 1, 5
# ...

# %%
fitnes,contEvaluacion = fitnesIndividuo(df,s,clusters,contEvaluacion)
# Out:
# Longitud cluster:  149
# Tamaño del Cluster:  149
# Longitud cluster:  177
# Tamaño del Cluster:  177
# Longitud cluster:  128
# Tamaño del Cluster:  128
# Longitud cluster:  141
# Tamaño del Cluster:  141
# Longitud cluster:  152
# Tamaño del Cluster:  152

# %%
a[0]
# Out:
# 0.5672249465429965

# %%
contEvaluacion
# Out:
# 4

# %%
Cruze1 =[3, 3, 3, 2, 3, 3, 2, 2, 3, 1, 1, 2, 3, 2, 2, 5, 2, 3, 2, 3, 1, 2, 3, 1, 3, 2, 3, 1, 3, 1, 
1, 2, 1, 3, 3, 2, 4, 4, 1, 1, 5, 3, 1, 2, 3, 5, 4, 3, 2, 5, 1, 4, 2, 2, 1, 4, 3, 1, 2, 3, 1, 4, 1, 2, 3, 3, 2, 3, 2, 2, 2, 1, 2, 4, 1, 4, 1, 4, 3, 3, 1, 1, 2, 3, 2, 2, 3, 2, 4, 2, 1, 3, 3, 2, 1, 1, 2, 3, 1, 3, 3, 5, 
2, 3, 3, 5, 3, 3, 4, 4, 1, 1, 2, 3, 3, 2, 3, 2, 3, 4, 3, 1, 2, 4, 3, 2, 2, 4, 1, 1, 3, 4, 2, 2, 3, 1, 3, 1, 4, 2, 3, 5, 1, 3, 5, 3, 2, 2, 1, 3, 2, 3, 3, 3, 2, 4, 4, 4, 3, 3, 1, 3, 3, 4, 1, 2, 3, 2, 2, 3, 1, 1, 2, 1, 2, 3, 1, 2, 3, 3, 1, 5, 3, 4, 2, 2, 2, 2, 1, 3, 4, 2, 1, 4, 2, 2, 3, 2, 2, 4, 3, 3, 5, 4, 2, 3, 1, 1, 3, 3, 3, 2, 3, 4, 1, 3, 1, 1, 1, 2, 1, 1, 3, 4, 2, 1, 1, 1, 3, 5, 2, 3, 4, 2, 3, 3, 1, 1, 4, 
1, 4, 4, 3, 2, 3, 3, 1, 2, 3, 3, 3, 3, 2, 3, 1, 2, 3, 1, 1, 1, 3, 2, 3, 2, 2, 3, 3, 1, 1, 3, 3, 3, 1, 5, 2, 2, 5, 3, 2, 4, 1, 2, 2, 4, 3, 2, 3, 3, 2, 1, 2, 3, 3, 4, 1, 3, 4, 3, 3, 5, 1, 3, 1, 3, 2, 1, 2, 3, 1, 3, 3, 1, 1, 2, 3, 2, 1, 3, 3, 4, 1, 4, 3, 1, 1, 2, 1, 3, 2, 5, 3, 3, 3, 3, 2, 3, 2, 3, 4, 2, 3, 2, 2, 1, 3, 1, 1, 1, 1, 4, 2, 2, 3, 5, 3, 1, 2, 1, 1, 4, 2, 2, 3, 2, 3, 2, 3, 2, 2, 5, 4, 2, 4, 4, 3, 2, 
2, 3, 2, 3, 3, 4, 3, 2, 3, 3, 1, 3, 3, 3, 4, 3, 3, 2, 5, 1]

# %%
vectorArray = np.array(Cruze2)
clus =  np.where(vectorArray == 5)
list_cls = clus[0].flatten().tolist()
# Se filtra el dataset deacuerdo a esos indices
df_cls = df[df.index.isin(list_cls)==True]

# %%
df_cls
# Out:
#     TIPO_SIEMBRA SEM_TRATADAS  DIST_SURCOS  DIST_PLANTAS COLOR_ENDOSPERMO  \
# 15        Manual           NO          0.8          0.20         Amarillo
# 125   Mecanizado           SI          0.8          0.13           Blanco
# 154   Mecanizado           NO          0.8          0.14           Blanco
# 164   Mecanizado           SI          0.8          0.20         Amarillo
# 186   Mecanizado           NO          0.8          0.14           Blanco
# 215   Mecanizado           NO          0.8          0.18           Blanco
# 221       Manual           NO          0.8          0.30         Amarillo
# 255   Mecanizado           NO          0.8          0.18           Blanco
# 259   Mecanizado           NO          0.8          0.14         Amarillo
# 270   Mecanizado           NO          0.8          0.20         Amarillo
# 283   Mecanizado           SI          0.8          0.18           Blanco
# 300   Mecanizado           NO          0.8          0.14         Amarillo
# ...

# %%
Pond_Radjustado = len(df_cls)
print(Pond_Radjustado)
# Se divide el dataset en conjunto de entrenamiento y pruebas [0.8 : Entrenamiento; 0.2: Testeo]
data_train, data_test = train_test_split(df_cls, test_size=0.2, random_state=42)
variables_independientes = '''~ C(MATERIAL_GENETICO) + C(TIPO_MATERIAL) +C(POSICION_PERFIL_RASTA) +C(ESTRUCTURA_RASTA) + C(OBSERVA_COSTRAS_DURAS_RASTA)
                                + C(OBSERVA_COSTRAS_BLANCAS_RASTA) + C(OBSERVA_COSTAS_NEGRAS_RASTA) + C(OBSERVA_PLANTAS_PEQUENAS_RASTA) + C(RECUBRIMIENTO_VEGETAL__SUELO_RASTA)
                                + C(TIPO_SIEMBRA)+ C(SEM_TRATADAS) + C(DIAS_EN_FLORECER_A_COSECHAR) +ContEnfQui_Emer_Flor + ContMalQui_Antes_Siem + ContMalQui_Emer_Flor
                                + ContPlaQui_Siem_Emer + PROFUND_RAICES_VIVAS_RASTA + Porc_Ar + Porc_FAr + Porc_BLANDO + Porc_FIRME + Porc_MUY_PLASTICO
'''
# Out:
# 30

# %%
data_test
# Out:
#     TIPO_SIEMBRA SEM_TRATADAS  DIST_SURCOS  DIST_PLANTAS COLOR_ENDOSPERMO  \
# 704   Mecanizado           NO          0.8          0.20           Blanco
# 400       Manual           NO          0.8          0.50         Amarillo
# 624       Manual           NO          0.8          0.30           Blanco
# 456       Manual           SI          0.8          0.50         Amarillo
# 259   Mecanizado           NO          0.8          0.14         Amarillo
# 270   Mecanizado           NO          0.8          0.20         Amarillo
#
#      SEM_POR_SITIO    MATERIAL_GENETICO CULT_ANT DRENAJE METODO_COSECHA  ...  \
# 704              1      P4082 (Pioneer)  Algodon      SI     Mecanizada  ...
# 400              3    PIONEER 30F35 HRR     Maiz      NO         Manual  ...
# 624              2      P4082 (Pioneer)     Maiz      NO         Manual  ...
# 456              3    PIONEER 30F35 HRR     Maiz      NO         Manual  ...
# ...

# %%
# Se crea el modelo
mod_cls = smf.ols(formula='RDT_AJUSTADO'+variables_independientes, data=data_train).fit()
#Me retorna el valor de la metrica de desempeño  para ese cluster.
fitnes_cls = mod_cls.rsquared_adj
# Out:
#   File "<ipython-input-50-eb30988390df>", line 5
#     isOK=all(isfinite([ep fitnes_cls]),2)
#                           ^
# SyntaxError: invalid syntax

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1650: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:1452: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           RDT_AJUSTADO   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):                nan
# Time:                        17:41:02   Log-Likelihood:                 557.61
# No. Observations:                  24   AIC:                            -1067.
# ...

# %%
#Me retorna el valor de la metrica de desempeño  para ese cluster.
fitnes_cls = mod_cls.rsquared_adj * Pond_Radjustado
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)

# %%
data_test

# %%
modelo = RegresionLineal(df_cls)

# %%
modelo
# Out:
# 76.04316231863476
